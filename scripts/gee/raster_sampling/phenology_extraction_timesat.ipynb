# %%
import pandas as pd
import numpy as np
import glob

# %%
d = '/mnt/poseidon/remotesensing/arctic/data/training/Test_04/original_files'
akveg = pd.read_csv(f'{d}/harmonicFitted_ndvi_AKVEG.csv', index_col=0)
akveg
# Out:
#              source  2019_10_fitted  2019_02_fitted  2019_04_fitted  \
# 0    AKVEG_AIM_NPRA     -477.833197    -1341.109699    -2023.910108
# 1    AKVEG_AIM_NPRA     -420.947413     -834.500917    -1232.216131
# 2    AKVEG_AIM_NPRA     -315.742630     -703.546293    -1191.553046
# 3    AKVEG_AIM_NPRA     -393.857258    -1135.239801    -1499.829009
# 4    AKVEG_AIM_NPRA     -312.604877     -523.136155     -984.377685
# ..              ...             ...             ...             ...
# 180  AKVEG_AIM_NPRA    -1147.596718    -2087.321398    -2338.344569
# 181  AKVEG_AIM_NPRA     -457.704622    -1377.621793    -1817.386777
# 182  AKVEG_AIM_NPRA    -1174.702254     -997.117324     -879.335204
# 183  AKVEG_AIM_NPRA     -347.224583     -216.452358      126.472325
# 184  AKVEG_AIM_NPRA    -1399.103403    -1964.082800     -787.309238
#
#      2019_06_fitted  2019_03_fitted  2019_08_fitted  year  2019_05_fitted  \
# 0       1877.739168     -866.929612     1881.957480  2015     -920.604817
# ...

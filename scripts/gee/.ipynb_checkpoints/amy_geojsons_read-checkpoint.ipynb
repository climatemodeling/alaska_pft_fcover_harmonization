# %%
import geemap as gee
import ee
import geopandas as gpd
import pandas as pd
import numpy as np

# %%
d = '/mnt/poseidon/remotesensing/arctic/data/vectors/AK-AVA_Turboveg/ak_tvexport_releves_header_data_for_vegbank_20181106_ALB.xlsx'
a = '/mnt/poseidon/remotesensing/arctic/data/vectors/AK-AVA_Turboveg/header_data_ckan_pubpage.xlsx'

# %%
data = pd.read_excel(d, na_values=-9)
# Out:
# /home/6ru/anaconda3/envs/gee/lib/python3.11/site-packages/openpyxl/worksheet/_read_only.py:81: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
data
# Out:
#       Releve number Field releve number  Date (yyyymmdd) Releve area (m2)  \
# 0               NaN                 NaN              NaN
# 1           10001.0               SWT-1       19890801.0               -1
# 2           10002.0               SWT-2       19890801.0               -1
# 3           10003.0               SWT-3       19890802.0               -1
# 4           10004.0               SWT-4       19890802.0               -1
# ...             ...                 ...              ...              ...
# 3635        30387.0            V-TR-R-4       19990808.0               15
# 3636        30388.0            V-TR-S-1       19990808.0                1
# 3637        30389.0            V-TR-S-2       19990808.0                1
# 3638        30390.0            V-TR-W-1       19990808.0               25
# 3639        30391.0            V-TR-W-2       19990808.0               25
#
#      Releve shape Cover abundance scale Repeat sampled (y/n) Collection  \
# 0             NaN                   NaN                  NaN        NaN
# 1       irregular  Braun/Blanquet (old)                    N     Relevé
# 2       irregular  Braun/Blanquet (old)                    N     Relevé
# 3       irregular  Braun/Blanquet (old)                    N     Relevé
# 4       irregular  Braun/Blanquet (old)                    N     Relevé
# ...           ...                   ...                  ...        ...
# 3635    irregular  Braun/Blanquet (old)                    N     Relevé
# 3636    irregular  Braun/Blanquet (old)                    N     Relevé
# 3637    irregular  Braun/Blanquet (old)                    N     Relevé
# 3638    irregular  Braun/Blanquet (old)                    N     Relevé
# 3639    irregular  Braun/Blanquet (old)                    N     Relevé
#
#      Collection method  Syntaxon  ... Cover rock (%) Cover water (%)  \
# 0                  NaN       NaN  ...            NaN             NaN
# 1                  NaN       NaN  ...            0.0             0.0
# 2                  NaN       NaN  ...            0.0             0.0
# 3                  NaN       NaN  ...            0.0             0.0
# 4                  NaN       NaN  ...            0.0           100.0
# ...                ...       ...  ...            ...             ...
# 3635               NaN       NaN  ...            0.0             0.0
# 3636               NaN       NaN  ...            5.0             0.0
# 3637               NaN       NaN  ...            0.0             0.0
# 3638               NaN       NaN  ...            0.0             0.0
# 3639               NaN       NaN  ...            0.0             0.0
#
#      Cover litter (%) Cover total vegetation (%) Mean canopy height (cm)  \
# 0                                            NaN                     NaN
# 1                 NaN                        NaN                    25.0
# 2                 NaN                        NaN                   200.0
# 3                 NaN                        NaN                    10.0
# 4                 NaN                        NaN                     0.0
# ...               ...                        ...                     ...
# 3635                0                       25.0                     NaN
# 3636               25                       90.0                     2.0
# 3637                2                        0.0                     4.0
# 3638               30                      100.0                    10.0
# 3639               20                      100.0                    10.0
#
#      Mean tree layer height (m) Mean shrub layer height (cm)  \
# 0                           NaN                          NaN
# 1                           NaN                          5.0
# 2                           NaN                         60.0
# 3                           NaN                          5.0
# 4                           NaN                          0.0
# ...                         ...                          ...
# 3635                        NaN                          NaN
# 3636                        NaN                          NaN
# 3637                        NaN                          NaN
# 3638                        NaN                          NaN
# 3639                        NaN                          NaN
#
#      Mean herb layer height (cm) Mean moss layer height (cm)  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# ...                          ...                         ...
# 3635                         NaN                         NaN
# 3636                         NaN                         NaN
# 3637                         NaN                         NaN
# 3638                         NaN                         NaN
# 3639                         NaN                         NaN
#
#                                                 Remarks
# 0                                                   NaN
# 1     Moist Carpod, Salcha, Potfru sedge, forb tundr...
# 2     Moist Salala, Calcan, Astsib tall shrubland, T...
# 3     Dry Betnan, Leddec, Claarb, dwarf-shrub, liche...
# 4     Unknown cyanobacteria = in orig. Nostoc commun...
# ...                                                 ...
# 3635  Damp fine sand along stream in floodplain. Ent...
# 3636  Transition between river bed and loamy terrace...
# 3637  Late-lying snowbed. Entered by L. Druckenmille...
# 3638  Cardamine polemonioides = in orig. Cardamine p...
# 3639  Elymus alaskanus = in orig. Elymus alaskanus s...
#
# [3640 rows x 70 columns]

# %%
import requests
import pandas as pd
from pyogrio import read_dataframe
from datetime import date, timedelta
from dateutil.relativedelta import relativedelta
import glob
import json
import numpy as np
import ee
import geemap as gee
import time
import standardize_pft_funcs as spf
import math

# %%
try:
    ee.Initialize()
except Exception as e:
    print('GEE token expired. Use Jupyter Lab to authenticate')
    ee.Authenticate()
# Out:
# GEE token expired. Use Jupyter Lab to authenticate
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=XFedqKI5VMDs6I5IM83btX6sKoBaA3Glyv8bzH28ozc&tc=OB5gdu_ZINb67Cs9X2wihlV80siwBSusW6hMdUhXECk&cc=_H9BhgIh6p3VixJj7UUNmiqgFVZw7tGEqE5iZo2JkNk>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=XFedqKI5VMDs6I5IM83btX6sKoBaA3Glyv8bzH28ozc&tc=OB5gdu_ZINb67Cs9X2wihlV80siwBSusW6hMdUhXECk&cc=_H9BhgIh6p3VixJj7UUNmiqgFVZw7tGEqE5iZo2JkNk</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AeaYSHCluEbV2vZbNTDGSs7f_Wi7stxW3T_fkKSruQO7ereHyr_92QpHUGc
# Successfully saved authorization token.

# %% [markdown]
# ## Load data

# %% [markdown]
# ### ELS team vegetation cover (20m-ish diameter, transect-quadrat sampling)

# %%
out_path = '/mnt/poseidon/remotesensing/arctic/data/vectors/ABR/'

# %%
# get els data
p = '/mnt/poseidon/remotesensing/arctic/data/vectors/ABR/'
f = 'veg_cover.csv'
els = pd.read_csv(p + f, index_col=0)

# %%
# load vegetation summary file to get top cover for litter
p = '/mnt/poseidon/remotesensing/arctic/data/vectors/ABR/'
f = 'veg.csv'
litter_info = pd.read_csv(p + f, index_col=0)
litter_info = litter_info[['plot_id', 'litter_alone_cover']]

# %%
# get plot info (lat, lon, etc)
p = '/mnt/poseidon/remotesensing/arctic/data/vectors/ABR/'
f = 'plot.csv'
ancillary = pd.read_csv(p + f, index_col=0)

# %%
# get els plot information
p = '/mnt/poseidon/remotesensing/arctic/data/vectors/ABR/'
f = 'els.csv'
els_info = pd.read_csv(p + f, index_col=0)

# %%
# drop rapid v-plots (verification plots) and get full plots only
fullplots = els_info[els_info['els_plot_type'] != 'Verification Plot']

# %%
# select els fcover data for full plots only
els_fullplots_fcover = fullplots.merge(els, on='plot_id')

# %%
len(fullplots)
# Out:
# 587

# %%
p = '/mnt/poseidon/remotesensing/arctic/data/vectors/ABR/'
f = 'ABR_ELS_only.csv'
els_fullplots_fcover.to_csv(p + f)

# %% [markdown]
# ## Get unqiue species list

# %%
abr = els_fullplots_fcover

# %%
species = spf.get_unique_species(DFRAME=abr, 
                                 SCOL='veg_taxonomy', 
                                 DNAME='ABR_ELS', 
                                 SAVE=True, 
                                 OUTP=out_path)
# Out:
# Saved unique species list to /mnt/poseidon/remotesensing/arctic/data/vectors/ABR//ABR_ELS_unique_species.csv.

# %% [markdown]
# ## Load species checklist

# %%
# load species checklist
p = '/mnt/poseidon/remotesensing/arctic/data/vectors/AKVEG_ACCS/'
f = 'AKVEG_species_checklist.csv'
checklist = read_dataframe(p + f)

# get first 2 words (genus-species) from checklist accepted name and data species name
checklist['Mapping Name'] = checklist['Accepted Name'].apply(spf.get_substrings)
species['Mapping Name'] = species['veg_taxonomy'].apply(spf.get_substrings)

# %%
habits = spf.fill_habits(unique_species=species, 
                         checklist=checklist, 
                         u_name='veg_taxonomy', 
                         c_unofficial_name='Name', 
                         c_official_name='Accepted Name', 
                         mapping_name='Mapping Name',
                         habit='Habit')
# Out:
# 253 species are missing habits.
# 127 species still missing habits.
# 31 species still missing habits.
# 27 species still missing habits.

# %% [markdown]
# ## Add evergreen/deciduous

# %%
p = '/mnt/poseidon/remotesensing/arctic/data/vectors/AK-AVA_post2000/'
f = 'evergreendecid_macander2022.csv'
evergrndecid = pd.read_csv(p + f, header=None)
evergrndecid.columns = ['evergreendecid', 'species']
final = spf.add_leaf_habit(habits, evergrndecid)

# %%
final
# Out:
#                          Name            Mapping Name Potential Habit  \
# index
# 0                         ???                     ???             NaN
# 1        Abietinella abietina    Abietinella abietina            moss
# 2        Achillea millefolium    Achillea millefolium            forb
# 3           Achillea sibirica       Achillea sibirica            forb
# 4               Agropyron sp.           Agropyron sp.       graminoid
# ...                       ...                     ...             ...
# 658      Warnstorfia fluitans    Warnstorfia fluitans            moss
# 659    Warnstorfia sarmentosa  Warnstorfia sarmentosa            moss
# 660                     Water                   Water             NaN
# 661       Wilhelmsia physodes     Wilhelmsia physodes            forb
# 662         Zygadenus elegans       Zygadenus elegans            forb
#
#            Habit Leaf Retention  Potential Height  Height
# index
# 0            NaN                              NaN     NaN
# 1           moss                              NaN     NaN
# 2           forb                              NaN     NaN
# 3           forb                              NaN     NaN
# 4      graminoid                              NaN     NaN
# ...          ...            ...               ...     ...
# 658         moss                              NaN     NaN
# 659         moss                              NaN     NaN
# 660          NaN                              NaN     NaN
# 661         forb                              NaN     NaN
# 662         forb                              NaN     NaN
#
# [663 rows x 7 columns]

# %%
# export
p = '/mnt/poseidon/remotesensing/arctic/data/vectors/ABR/'
f = 'ABR_ELS_species_habit_00.csv'
final.to_csv(p + f)

# %%
list(final['Potential Habit'].unique())
# Out:
# [nan,
#  'moss',
#  'forb',
#  'graminoid',
#  'lichen',
#  'shrub',
#  'liverwort',
#  'dwarf shrub',
#  ' shrub,shrub, dwarf shrub, forb',
#  'spore-bearing',
#  ' shrub,dwarf shrub',
#  ' tree, shrub,shrub, dwarf shrub, deciduous tree']

# %% [markdown]
# ## Export shrubs, nonshrubs, null habit seperately

# %%
# get all shrub species
finalnonnull = final[~final['Potential Habit'].isnull()]
shrubs = finalnonnull[finalnonnull['Potential Habit'].str.contains('shrub')]
shrubs.to_csv(p + 'ABR_ELS_shrubs_00.csv')

# %%
# get all non-shrub species
nonshrubs = finalnonnull[~finalnonnull['Potential Habit'].str.contains('shrub')]
nonshrubs.to_csv(p + 'ABR_ELS_nonshrubs_00.csv')

# %%
# get null habits
finalnull = final[final['Potential Habit'].isnull()]
finalnull.to_csv(p + 'ABR_ELS_nullhabit_00.csv')

# %%
len(finalnull) + len(nonshrubs) + len(shrubs)
# Out:
# 663

# %%
len(final)
# Out:
# 663

# %% [markdown]
# ## HERE: Manually add data for shrubs00 and nullhabit00

# %% [markdown]
# ## Standardize PFT Schema

# %%
p = '/mnt/poseidon/remotesensing/arctic/data/vectors/ABR/'
nonshrub = 'ABR_ELS_nonshrubs_00.csv'
null = 'ABR_ELS_nullhabit_01.csv'
shrub = 'ABR_ELS_shrubs_01.csv'

alltypes = [nonshrub, shrub, null]

d = []
for t in alltypes:
    habits = pd.read_csv(p + t, index_col=0)
    d.append(habits)

# %%
completehabits = pd.concat(d)
completehabits['Habit'].unique().tolist()
# Out:
# ['moss',
#  'forb',
#  'graminoid',
#  'lichen',
#  'liverwort',
#  'spore-bearing',
#  'shrub',
#  'dwarf shrub',
#  'shrub, tree',
#  'unknown',
#  'bare mineral',
#  'bare rock',
#  'litter',
#  'algae',
#  'fungus',
#  'grass',
#  'water']

# %%
def standardize_habit(habitrow, leafrow, heightrow):
    
    habitrow = habitrow.to_numpy()
    leafrow = leafrow.to_numpy()
    heightrow = heightrow.to_numpy()
    new_row = []
    
    for habit, leaf, height in zip(habitrow, leafrow, heightrow):
        habit = habit.lower()
        if 'algae' in habit:
            new_habit = 'lichen cover (%)'
        elif habit == np.nan or 'unknown' in habit:
            new_habit = 'unknown cover (%)'
        elif 'moss' in habit or 'liverwort' in habit:
            new_habit = 'bryophyte cover (%)'
        elif 'spore-bearing' in habit:
            new_habit = 'forb cover (%)'
        elif habit == 'grass':
            new_habit = 'graminoid cover (%)'
        elif habit == 'dwarf shrub':
            new_habit = f'{leaf} {habit} cover (%)'
        elif height == 'dwarf to low shrub':
            new_habit = f'{leaf} {height} cover (%)'
        elif height == 'dwarf to tall shrub':
            new_habit = f'{leaf} {height} cover (%)'
        elif habit == 'shrub, tree':
            new_habit = f'{leaf} shrub to tree cover (%)'
        else:
            new_habit = f'{habit} cover (%)'
        new_row.append(" ".join(new_habit.split()).lower())
    
    return new_row
        
new_habit_col = standardize_habit(completehabits['Habit'], 
                                  completehabits['Leaf Retention'], 
                                  completehabits['Height'])

# %%
set(new_habit_col)
# Out:
# {'bare mineral cover (%)',
#  'bare rock cover (%)',
#  'bryophyte cover (%)',
#  'deciduous dwarf shrub cover (%)',
#  'deciduous dwarf to low shrub cover (%)',
#  'deciduous dwarf to tall shrub cover (%)',
#  'deciduous shrub to tree cover (%)',
#  'evergreen dwarf shrub cover (%)',
#  'evergreen dwarf to low shrub cover (%)',
#  'forb cover (%)',
#  'fungus cover (%)',
#  'graminoid cover (%)',
#  'lichen cover (%)',
#  'litter cover (%)',
#  'unknown cover (%)',
#  'water cover (%)'}

# %%
completehabits['Standard Habit'] = new_habit_col

# %%
p = '/mnt/poseidon/remotesensing/arctic/data/vectors/ABR/'
f = 'ABR_ELS_species_habit_standardized.csv'
completehabits.to_csv(p + f)

# %%
completehabits
# Out:
#                        Name          Mapping Name Potential Habit      Habit  \
# index
# 1      Abietinella abietina  Abietinella abietina            moss       moss
# 2      Achillea millefolium  Achillea millefolium            forb       forb
# 3         Achillea sibirica     Achillea sibirica            forb       forb
# 4             Agropyron sp.         Agropyron sp.       graminoid  graminoid
# 5           Agrostis scabra       Agrostis scabra       graminoid  graminoid
# ...                     ...                   ...             ...        ...
# 644          Unknown moss 2                  moss            moss       moss
# 645          Unknown moss 3                  moss            moss       moss
# 646          Unknown moss 4                  moss            moss       moss
# 647          Unknown moss 5                  moss            moss       moss
# 660                   Water                 Water           Water      water
#
#       Leaf Retention Potential Height Height       Standard Habit
# index
# 1                NaN              NaN    NaN  bryophyte cover (%)
# 2                NaN              NaN    NaN       forb cover (%)
# 3                NaN              NaN    NaN       forb cover (%)
# 4                NaN              NaN    NaN  graminoid cover (%)
# 5                NaN              NaN    NaN  graminoid cover (%)
# ...              ...              ...    ...                  ...
# 644              NaN              NaN    NaN  bryophyte cover (%)
# 645              NaN              NaN    NaN  bryophyte cover (%)
# 646              NaN              NaN    NaN  bryophyte cover (%)
# 647              NaN              NaN    NaN  bryophyte cover (%)
# 660              NaN              NaN    NaN      water cover (%)
#
# [663 rows x 8 columns]

# %% [markdown]
# ## Join habit to fcover data

# %%
abr = abr.reset_index()

# %%
withfcover = abr.merge(completehabits, left_on='veg_taxonomy', right_on='Name')

# %%
withfcover
# Out:
#        index project_id_x            plot_id          veg_observer  \
# 0          0   12-258.6.1  NPRA_T115_15_2012         Aaron F Wells
# 1        477   12-258.6.1  NPRA_T160_08_2012       Ellen R Trainor
# 2       3477   12-258.6.1  NPRA_T014_02_2012        Erin K Johnson
# 3          1   12-258.6.1  NPRA_T115_15_2012         Aaron F Wells
# 4         45   12-258.6.1  NPRA_T115_03_2012       Ellen R Trainor
# ...      ...          ...                ...                   ...
# 12421  11823   12-258.6.1  NPRA_T144_11_2012        Erin K Johnson
# 12422  11849   12-258.6.1  NPRA_T019_05_2012  Louise M Farquharson
# 12423  11877       11-257   CHCO_T29_07_2011         Wendy A Davis
# 12424  12029   12-258.5.1           120810b2     Martha K Raynolds
# 12425  12222   12-258.6.1  NPRA_T115_02_2012       Ellen R Trainor
#
#                env_observer env_field_start_ts  \
# 0           Michael S Davis  07/17/12 17:50:02
# 1           Michael S Davis  08/08/12 11:28:36
# 2      Tracy Christopherson  07/21/12 11:31:38
# 3           Michael S Davis  07/17/12 17:50:02
# 4               Anja N Kade  07/17/12 14:58:25
# ...                     ...                ...
# 12421  Tracy Christopherson  07/19/12 16:46:24
# 12422           Anja N Kade  08/14/12 14:02:24
# 12423         Aaron F Wells  07/19/11 00:00:00
# 12424      Kimberly S Allen  08/10/12 14:17:04
# 12425           Anja N Kade  07/17/12 12:53:27
#
#                           study_location data_origin els_plot_type  \
# 0      National Petroleum Reserve Alaska    ABR Inc.     Full Plot
# 1      National Petroleum Reserve Alaska    ABR Inc.     Full Plot
# 2      National Petroleum Reserve Alaska    ABR Inc.     Full Plot
# 3      National Petroleum Reserve Alaska    ABR Inc.     Full Plot
# 4      National Petroleum Reserve Alaska    ABR Inc.     Full Plot
# ...                                  ...         ...           ...
# 12421  National Petroleum Reserve Alaska    ABR Inc.     Full Plot
# 12422  National Petroleum Reserve Alaska    ABR Inc.     Full Plot
# 12423                  Chukchi Sea Coast    ABR Inc.     Full Plot
# 12424  National Petroleum Reserve Alaska    ABR Inc.     Full Plot
# 12425  National Petroleum Reserve Alaska    ABR Inc.     Full Plot
#
#       plot_radius  ...                           plot_uuid_y  \
# 0      10m radius  ...                                   NaN
# 1      10m radius  ...                                   NaN
# 2      10m radius  ...                                   NaN
# 3      10m radius  ...                                   NaN
# 4      10m radius  ...                                   NaN
# ...           ...  ...                                   ...
# 12421  10m radius  ...                                   NaN
# 12422        4x8m  ...                                   NaN
# 12423      10x10m  ...  f14a5f84-6f62-11e4-9db1-0025902deb10
# 12424  10m radius  ...                                   NaN
# 12425  10m radius  ...                                   NaN
#
#                        veg_observation_uuid                       Name  \
# 0      3782964c-7fd5-11e4-b9fe-0025902deb10       Lopadium pezizoideum
# 1      37831e6e-7fd5-11e4-b035-0025902deb10       Lopadium pezizoideum
# 2      37820826-7fd5-11e4-99d0-0025902deb10       Lopadium pezizoideum
# 3      3782964c-7fd5-11e4-b9fe-0025902deb10             Luzula confusa
# 4      37829002-7fd5-11e4-9829-0025902deb10             Luzula confusa
# ...                                     ...                        ...
# 12421  3782e052-7fd5-11e4-9e9b-0025902deb10          Lophozia wenzelii
# 12422  37821672-7fd5-11e4-be6b-0025902deb10        Paludella squarrosa
# 12423  18a6895e-6f81-11e4-97a1-0025902deb10      Pseudephebe pubescens
# 12424  3783daf2-7fd5-11e4-b345-0025902deb10            Baeomyces rufus
# 12425  37828f26-7fd5-11e4-99ce-0025902deb10  Allium schoenoprasum s.l.
#
#                 Mapping Name Potential Habit      Habit Leaf Retention  \
# 0       Lopadium pezizoideum          lichen     lichen            NaN
# 1       Lopadium pezizoideum          lichen     lichen            NaN
# 2       Lopadium pezizoideum          lichen     lichen            NaN
# 3             Luzula confusa       graminoid  graminoid            NaN
# 4             Luzula confusa       graminoid  graminoid            NaN
# ...                      ...             ...        ...            ...
# 12421      Lophozia wenzelii       liverwort  liverwort            NaN
# 12422    Paludella squarrosa            moss       moss            NaN
# 12423  Pseudephebe pubescens          lichen     lichen            NaN
# 12424        Baeomyces rufus          lichen     lichen            NaN
# 12425   Allium schoenoprasum            forb       forb            NaN
#
#       Potential Height Height       Standard Habit
# 0                  NaN    NaN     lichen cover (%)
# 1                  NaN    NaN     lichen cover (%)
# 2                  NaN    NaN     lichen cover (%)
# 3                  NaN    NaN  graminoid cover (%)
# 4                  NaN    NaN  graminoid cover (%)
# ...                ...    ...                  ...
# 12421              NaN    NaN  bryophyte cover (%)
# 12422              NaN    NaN  bryophyte cover (%)
# 12423              NaN    NaN     lichen cover (%)
# 12424              NaN    NaN     lichen cover (%)
# 12425              NaN    NaN       forb cover (%)
#
# [12426 rows x 91 columns]

# %%
#grouped = withfcover.groupby(['plot_id', 'Standard Habit'], group_keys=True).agg({'species_cover': 'sum'})
grouped = withfcover.groupby(['plot_id', 'Standard Habit'], group_keys=True).agg({'cover_percent': 'sum'})

# %%
grouped
# Out:
#                                                            cover_percent
# plot_id           Standard Habit
# 120729b1          bryophyte cover (%)                               23.1
#                   deciduous dwarf shrub cover (%)                    0.1
#                   deciduous dwarf to low shrub cover (%)            16.1
#                   deciduous dwarf to tall shrub cover (%)            1.0
#                   evergreen dwarf shrub cover (%)                   13.0
# ...                                                                  ...
# NPRA_V073_01_2012 evergreen dwarf shrub cover (%)                    1.0
#                   evergreen dwarf to low shrub cover (%)             1.0
#                   forb cover (%)                                     2.1
#                   fungus cover (%)                                   0.1
#                   graminoid cover (%)                               23.1
#
# [3712 rows x 1 columns]

# %%
grouped.columns = grouped.columns.get_level_values(0)
grouped = grouped.reset_index()
grouped
# Out:
#                 plot_id                           Standard Habit  \
# 0              120729b1                      bryophyte cover (%)
# 1              120729b1          deciduous dwarf shrub cover (%)
# 2              120729b1   deciduous dwarf to low shrub cover (%)
# 3              120729b1  deciduous dwarf to tall shrub cover (%)
# 4              120729b1          evergreen dwarf shrub cover (%)
# ...                 ...                                      ...
# 3707  NPRA_V073_01_2012          evergreen dwarf shrub cover (%)
# 3708  NPRA_V073_01_2012   evergreen dwarf to low shrub cover (%)
# 3709  NPRA_V073_01_2012                           forb cover (%)
# 3710  NPRA_V073_01_2012                         fungus cover (%)
# 3711  NPRA_V073_01_2012                      graminoid cover (%)
#
#       cover_percent
# 0              23.1
# 1               0.1
# 2              16.1
# 3               1.0
# 4              13.0
# ...             ...
# 3707            1.0
# 3708            1.0
# 3709            2.1
# 3710            0.1
# 3711           23.1
#
# [3712 rows x 3 columns]

# %%
groups = grouped.set_index(['plot_id', 'Standard Habit']).stack().unstack([1,2])
groups.columns = groups.columns.get_level_values(0)
groups = groups.reset_index()
groups
# Out:
# Standard Habit            plot_id  bryophyte cover (%)  \
# 0                        120729b1                 23.1
# 1                        120729b2                 83.2
# 2                        120730b1                 35.2
# 3                        120730b2                 17.1
# 4                        120730b3                 15.0
# ..                            ...                  ...
# 580             NPRA_T503_05_2012                  0.1
# 581             NPRA_T610_02_2012                 18.5
# 582             NPRA_T625_01_2012                 33.3
# 583             NPRA_T629_03_2012                  1.6
# 584             NPRA_V073_01_2012                 38.1
#
# Standard Habit  deciduous dwarf shrub cover (%)  \
# 0                                           0.1
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 580                                         NaN
# 581                                         5.1
# 582                                         1.0
# 583                                         NaN
# 584                                         NaN
#
# Standard Habit  deciduous dwarf to low shrub cover (%)  \
# 0                                                 16.1
# 1                                                 23.1
# 2                                                 32.0
# 3                                                 12.0
# 4                                                 13.0
# ..                                                 ...
# 580                                                NaN
# 581                                               15.0
# 582                                               10.0
# 583                                                NaN
# 584                                               14.0
#
# Standard Habit  deciduous dwarf to tall shrub cover (%)  \
# 0                                                   1.0
# 1                                                   1.0
# 2                                                   5.0
# 3                                                   3.0
# 4                                                   3.0
# ..                                                  ...
# 580                                                 NaN
# 581                                                 5.1
# 582                                                 2.0
# 583                                                 1.0
# 584                                                 2.0
#
# Standard Habit  evergreen dwarf shrub cover (%)  \
# 0                                          13.0
# 1                                           0.1
# 2                                           2.0
# 3                                           1.0
# 4                                           1.0
# ..                                          ...
# 580                                         NaN
# 581                                         8.1
# 582                                        13.0
# 583                                         NaN
# 584                                         1.0
#
# Standard Habit  evergreen dwarf to low shrub cover (%)  forb cover (%)  \
# 0                                                 20.0             4.6
# 1                                                  0.1             0.1
# 2                                                  NaN             3.1
# 3                                                  NaN             1.1
# 4                                                  NaN             5.0
# ..                                                 ...             ...
# 580                                                NaN             0.2
# 581                                               10.0             6.3
# 582                                                6.0             0.3
# 583                                                NaN             6.4
# 584                                                1.0             2.1
#
# Standard Habit  graminoid cover (%)  lichen cover (%)  fungus cover (%)  \
# 0                               5.3               3.5               NaN
# 1                              20.1               NaN               NaN
# 2                              16.0               NaN               NaN
# 3                              17.1               NaN               NaN
# 4                              20.0               NaN               NaN
# ..                              ...               ...               ...
# 580                             0.1               NaN               NaN
# 581                             9.2               1.9               NaN
# 582                            21.1              38.4               NaN
# 583                            16.5               NaN               NaN
# 584                            23.1               NaN               0.1
#
# Standard Habit  water cover (%)  bare mineral cover (%)  litter cover (%)  \
# 0                           NaN                     NaN               NaN
# 1                           NaN                     NaN               NaN
# 2                           NaN                     NaN               NaN
# 3                           NaN                     NaN               NaN
# 4                           NaN                     NaN               NaN
# ..                          ...                     ...               ...
# 580                       100.0                     NaN               NaN
# 581                         NaN                     NaN               NaN
# 582                         NaN                     NaN               NaN
# 583                         NaN                     NaN               NaN
# 584                         NaN                     NaN               NaN
#
# Standard Habit  deciduous shrub to tree cover (%)  unknown cover (%)  \
# 0                                             NaN                NaN
# 1                                             NaN                NaN
# 2                                             NaN                NaN
# 3                                             NaN                NaN
# 4                                             NaN                NaN
# ..                                            ...                ...
# 580                                           NaN                NaN
# 581                                           NaN                NaN
# 582                                           NaN                NaN
# 583                                           NaN                NaN
# 584                                           NaN                NaN
#
# Standard Habit  bare rock cover (%)
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 580                             NaN
# 581                             NaN
# 582                             NaN
# 583                             NaN
# 584                             NaN
#
# [585 rows x 17 columns]

# %% [markdown]
# ## Add frost boils cover (not sure if necessary)

# %%
# prep frost boil data for concatenating
frostboil_perc = fullplots.copy()
frostboil_perc['frost boil cover (%)'] = frostboil_perc['frost_boil_cover_percent']
frostboil_perc = frostboil_perc[['plot_id', 'frost boil cover (%)', 'plot_radius']]

# %%
groups = groups.merge(frostboil_perc, on='plot_id')

# %%
groups.columns.tolist()
# Out:
# ['plot_id',
#  'bryophyte cover (%)',
#  'deciduous dwarf shrub cover (%)',
#  'deciduous dwarf to low shrub cover (%)',
#  'deciduous dwarf to tall shrub cover (%)',
#  'evergreen dwarf shrub cover (%)',
#  'evergreen dwarf to low shrub cover (%)',
#  'forb cover (%)',
#  'graminoid cover (%)',
#  'lichen cover (%)',
#  'fungus cover (%)',
#  'water cover (%)',
#  'bare mineral cover (%)',
#  'litter cover (%)',
#  'deciduous shrub to tree cover (%)',
#  'unknown cover (%)',
#  'bare rock cover (%)',
#  'frost boil cover (%)',
#  'plot_radius']

# %%
# required columns
necessary_cols = ['deciduous dwarf shrub cover (%)',
                  'deciduous dwarf to low shrub cover (%)',
                  'deciduous dwarf to tall shrub cover (%)',
                  'deciduous shrub to tree cover (%)',
                  'deciduous tree cover (%)',
                  'evergreen dwarf shrub cover (%)',
                  'evergreen dwarf to low shrub cover (%)',
                  'evergreen dwarf to tall shrub cover (%)',
                  'evergreen shrub to tree cover (%)',
                  'evergreen tree cover (%)',
                  'bryophyte cover (%)',
                  'forb cover (%)',
                  'graminoid cover (%)',
                  'lichen cover (%)']

# %%
cols = groups.columns.tolist()
addcols = []
for nc in necessary_cols:
    if nc not in cols:
        addcols.append(nc)

# %%
addcols
# Out:
# ['deciduous tree cover (%)',
#  'evergreen dwarf to tall shrub cover (%)',
#  'evergreen shrub to tree cover (%)',
#  'evergreen tree cover (%)']

# %%
groups[addcols] = np.nan

# %%
groups['source'] = 'ABR_ELS'

# %%
finaldata = groups.merge(ancillary, on='plot_id')

# %%
finaldata['year'] = pd.DatetimeIndex(finaldata['field_start_ts']).year

# %%
finaldata['year'] = finaldata['year'].astype('Int64')

# %%
finaldata['source_context'] = 'mapping vegetation'

# %%
# add litter top cover
finaldata = finaldata.merge(litter_info, on='plot_id')
finaldata['litter top cover (%)'] = finaldata['litter_alone_cover']
finaldata.drop(columns=['litter_alone_cover'], inplace=True)

# %%
finaldata.columns.tolist()
# Out:
# ['plot_id',
#  'bryophyte cover (%)',
#  'deciduous dwarf shrub cover (%)',
#  'deciduous dwarf to low shrub cover (%)',
#  'deciduous dwarf to tall shrub cover (%)',
#  'evergreen dwarf shrub cover (%)',
#  'evergreen dwarf to low shrub cover (%)',
#  'forb cover (%)',
#  'graminoid cover (%)',
#  'lichen cover (%)',
#  'fungus cover (%)',
#  'water cover (%)',
#  'bare mineral cover (%)',
#  'litter cover (%)',
#  'deciduous shrub to tree cover (%)',
#  'unknown cover (%)',
#  'bare rock cover (%)',
#  'frost boil cover (%)',
#  'plot_radius',
#  'deciduous tree cover (%)',
#  'evergreen dwarf to tall shrub cover (%)',
#  'evergreen shrub to tree cover (%)',
#  'evergreen tree cover (%)',
#  'source',
#  'project_id',
#  'area_id',
#  'transect_id',
#  'superplot_id',
#  'subplot_id',
#  'plot_type',
#  'latitude',
#  'longitude',
#  'elevation_m',
#  'h_datum',
#  'v_datum',
#  'loc_origin',
#  'extra',
#  'plot_uuid_array',
#  'field_start_ts',
#  'year',
#  'source_context',
#  'litter top cover (%)']

# %%
# combine non-vegetation top cover columns
finaldata2 = finaldata.copy()
finaldata2['bare ground top cover (%)'] = finaldata2['bare mineral cover (%)'] + finaldata2['bare rock cover (%)']
finaldata2.drop(columns=['bare mineral cover (%)', 
                         'bare rock cover (%)',
                         'litter cover (%)'], inplace=True)

# %%
# rename water
finaldata2.rename(columns={'water cover (%)':'water top cover (%)'}, inplace=True)

# %%
p = '/mnt/poseidon/remotesensing/arctic/data/training/Test_04/'
f = 'ABR_ELS_pft_fcover_00.csv'
finaldata2.to_csv(p + f)

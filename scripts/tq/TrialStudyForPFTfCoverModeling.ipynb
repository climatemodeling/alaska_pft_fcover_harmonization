# %%
import pandas as pd
Plotmed = pd.read_csv('plant_cover_2017_huc190604_aggregated.csv')

# %%
Plotmed
# Out:
#                                                  uid   of_microsite   shrubs  \
# 0                   Frost_Boils_Environmental_Data_0            NaN      NaN
# 1                   Frost_Boils_Environmental_Data_1            NaN      NaN
# 2                   Frost_Boils_Environmental_Data_2            NaN      NaN
# 3                   Frost_Boils_Environmental_Data_3            NaN      NaN
# 4                   Frost_Boils_Environmental_Data_4            NaN      NaN
# 5                   Frost_Boils_Environmental_Data_5            NaN      NaN
# 6                   Frost_Boils_Environmental_Data_6            NaN      NaN
# 7                   Frost_Boils_Environmental_Data_7            NaN      NaN
# 8                   Frost_Boils_Environmental_Data_8            NaN      NaN
# 9                   Frost_Boils_Environmental_Data_9            NaN      NaN
# 10                 Frost_Boils_Environmental_Data_10            NaN      NaN
# ...

# %%
Plotmed_orig = pd.read_csv('plant_cover_2017_huc190604.csv')
Plotmed_orig
# Out:
#                                                  uid graminoids forbs  \
# 0                   Frost_Boils_Environmental_Data_0        NaN   NaN
# 1                   Frost_Boils_Environmental_Data_1        NaN   NaN
# 2                   Frost_Boils_Environmental_Data_2        NaN   NaN
# 3                   Frost_Boils_Environmental_Data_3        NaN   NaN
# 4                   Frost_Boils_Environmental_Data_4        NaN   NaN
# 5                   Frost_Boils_Environmental_Data_5        NaN   NaN
# 6                   Frost_Boils_Environmental_Data_6        NaN   NaN
# 7                   Frost_Boils_Environmental_Data_7        NaN   NaN
# 8                   Frost_Boils_Environmental_Data_8        NaN   NaN
# 9                   Frost_Boils_Environmental_Data_9        NaN   NaN
# 10                 Frost_Boils_Environmental_Data_10        NaN   NaN
# 11                 Frost_Boils_Environmental_Data_11        NaN   NaN
# ...

# %%
import openeo
import pandas as pd

# %%
# connect to openeo
connection = openeo.connect("https://openeocloud.vito.be/openeo/1.0.0")
connection.list_collection_ids()[:5]
# Out:
# ['MAPEO_WATER_TUR_V1',
#  'COP_DEM_EU_25M',
#  'ESA_WORLDCEREAL_ACTIVECROPLAND',
#  'ESA_WORLDCEREAL_IRRIGATION',
#  'ESA_WORLDCEREAL_TEMPORARYCROPS']

# %%
# Authenticate with OIDC authentication"
connection.authenticate_oidc()
# Out:
# Authenticated using refresh token.
# <Connection to 'https://openeocloud.vito.be/openeo/1.0.0' with OidcBearerAuth>

# %%
# see https://docs.openeo.cloud/data-collections/
# and https://hub.openeo.org/
datacube = connection.load_collection(collection_id='SENTINEL1_GRD',
                                      properties=['sar:instrument_mode' == 2, #IW
                                                  'sar:satellite:orbit_state' == 2, #descending
                                                  'sar:resolution' == 1, #10 range, 10 azimuth; max ability to distinguish 2 close scatters
                                                  'sar:range_pixel_spacing' == 1, #10m pixel size
                                                  'data_type' == 'gamma0',
                                                  'bands' == ['VH', 'HH', 'HV', 'VV'],
                                                  'orthorectify' == 'true'])

# %%
def divide_bounds(min_y, max_y, n):
    
    north_lats = []
    south_lats = []
    step = (max_y - min_y) / n
    
    for i in range(n):
        north = max_y - i * step
        south = north - step
        north_lats.append(round(north, 1))
        south_lats.append(round(south, 1))
        
    return north_lats, south_lats

# %%
# set min and max lat and number of steps
min_y = 52
max_y = 72
min_x = -169.1
max_x = -139.8

# do it
norths, souths = divide_bounds(min_y, max_y, 8)
easts, wests = divide_bounds(min_x, max_x, 8)

# %%
print(norths, souths, wests, easts)
# Out:
# [72.0, 69.5, 67.0, 64.5, 62.0, 59.5, 57.0, 54.5] [69.5, 67.0, 64.5, 62.0, 59.5, 57.0, 54.5, 52.0] [-143.5, -147.1, -150.8, -154.4, -158.1, -161.8, -165.4, -169.1] [-139.8, -143.5, -147.1, -150.8, -154.4, -158.1, -161.8, -165.4]

# %%
i = 0

# filter by location, date, and bands
datacube = datacube.filter_bbox(west=wests[i], south=souths[i], east=easts[i], north=norths[i])
datacube = datacube.filter_temporal(start_date="2019-06-01", end_date="2019-08-31")
datacube = datacube.filter_bands(["VV", "VH"])

# %%
# mask and create median
masked_datacube = datacube.apply(lambda x:x <= -30.0)
datacube = datacube.mask(masked_datacube)
med_summer = datacube.median_time()

# %%
# backscatter
med_summer = med_summer.sar_backscatter(coefficient='gamma0-ellipsoid')

# %%
med_summer.print_json()
# Out:
# {
#   "process_graph": {
#     "loadcollection1": {
#       "process_id": "load_collection",
#       "arguments": {
#         "id": "SENTINEL1_GRD",
#         "spatial_extent": null,
#         "temporal_extent": null
#       }
#     },
#     "filterbbox1": {
#       "process_id": "filter_bbox",
#       "arguments": {
#         "data": {
#           "from_node": "loadcollection1"
#         },
#         "extent": {
#           "west": -143.5,
#           "east": -139.8,
#           "north": 72.0,
#           "south": 69.5
#         }
#       }
#     },
#     "filtertemporal1": {
#       "process_id": "filter_temporal",
#       "arguments": {
#         "data": {
#           "from_node": "filterbbox1"
#         },
#         "extent": [
#           "2019-06-01",
#           "2019-08-31"
#         ]
#       }
#     },
#     "filterbands1": {
#       "process_id": "filter_bands",
#       "arguments": {
#         "bands": [
#           "VV",
#           "VH"
#         ],
#         "data": {
#           "from_node": "filtertemporal1"
#         }
#       }
#     },
#     "apply1": {
#       "process_id": "apply",
#       "arguments": {
#         "data": {
#           "from_node": "filterbands1"
#         },
#         "process": {
#           "process_graph": {
#             "lte1": {
#               "process_id": "lte",
#               "arguments": {
#                 "x": {
#                   "from_parameter": "x"
#                 },
#                 "y": -30.0
#               },
#               "result": true
#             }
#           }
#         }
#       }
#     },
#     "mask1": {
#       "process_id": "mask",
#       "arguments": {
#         "data": {
#           "from_node": "filterbands1"
#         },
#         "mask": {
#           "from_node": "apply1"
#         }
#       }
#     },
#     "reducedimension1": {
#       "process_id": "reduce_dimension",
#       "arguments": {
#         "data": {
#           "from_node": "mask1"
#         },
#         "dimension": "t",
#         "reducer": {
#           "process_graph": {
#             "median1": {
#               "process_id": "median",
#               "arguments": {
#                 "data": {
#                   "from_parameter": "data"
#                 }
#               },
#               "result": true
#             }
#           }
#         }
#       }
#     },
#     "sarbackscatter1": {
#       "process_id": "sar_backscatter",
#       "arguments": {
#         "coefficient": "gamma0-ellipsoid",
#         "contributing_area": false,
#         "data": {
#           "from_node": "reducedimension1"
#         },
#         "elevation_model": null,
#         "ellipsoid_incidence_angle": false,
#         "local_incidence_angle": false,
#         "mask": false,
#         "noise_removal": true
#       },
#       "result": true
#     }
#   }
# }

# %%
# create result
result = med_summer.save_result(format="GTiff")
result
# Out:
#     <script>
#     if (!window.customElements || !window.customElements.get('openeo-model-builder')) {
#         var el = document.createElement('script');
#         el.src = "https://cdn.jsdelivr.net/npm/@openeo/vue-components@2/assets/openeo.min.js";
#         document.head.appendChild(el);
#
#         var font = document.createElement('font');
#         font.as = "font";
#         font.type = "font/woff2";
#         font.crossOrigin = true;
#         font.href = "https://use.fontawesome.com/releases/v5.13.0/webfonts/fa-solid-900.woff2"
#         document.head.appendChild(font);
#     }
#     </script>
#     <openeo-model-builder>
#         <script type="application/json">{"id": "d374243d03e0453a9368b5804759fae4", "explicit-zoom": true, "height": "400px", "value": {"process_graph": {"loadcollection1": {"process_id": "load_collection", "arguments": {"id": "SENTINEL1_GRD", "spatial_extent": null, "temporal_extent": null}}, "filterbbox1": {"process_id": "filter_bbox", "arguments": {"data": {"from_node": "loadcollection1"}, "extent": {"west": -143.5, "east": -139.8, "north": 72.0, "south": 69.5}}}, "filtertemporal1": {"process_id": "filter_temporal", "arguments": {"data": {"from_node": "filterbbox1"}, "extent": ["2019-06-01", "2019-08-31"]}}, "filterbands1": {"process_id": "filter_bands", "arguments": {"bands": ["VV", "VH"], "data": {"from_node": "filtertemporal1"}}}, "apply1": {"process_id": "apply", "arguments": {"data": {"from_node": "filterbands1"}, "process": {"process_graph": {"lte1": {"process_id": "lte", "arguments": {"x": {"from_parameter": "x"}, "y": -30.0}, "result": true}}}}}, "mask1": {"process_id": "mask", "arguments": {"data": {"from_node": "filterbands1"}, "mask": {"from_node": "apply1"}}}, "reducedimension1": {"process_id": "reduce_dimension", "arguments": {"data": {"from_node": "mask1"}, "dimension": "t", "reducer": {"process_graph": {"median1": {"process_id": "median", "arguments": {"data": {"from_parameter": "data"}}, "result": true}}}}}, "sarbackscatter1": {"process_id": "sar_backscatter", "arguments": {"coefficient": "gamma0-ellipsoid", "contributing_area": false, "data": {"from_node": "reducedimension1"}, "elevation_model": null, "ellipsoid_incidence_angle": false, "local_incidence_angle": false, "mask": false, "noise_removal": true}}, "saveresult1": {"process_id": "save_result", "arguments": {"data": {"from_node": "sarbackscatter1"}, "format": "GTiff", "options": {}}, "result": true}}}}</script>
#     </openeo-model-builder>

# %%
result.download()
# Out:
# ---------------------------------------------------------------------------
# OpenEoApiError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 result.download()
#
# File ~/anaconda3/envs/gee/lib/python3.11/site-packages/openeo/rest/datacube.py:2079, in DataCube.download(self, outputfile, format, options, validate)
#    2077     format = guess_format(outputfile)
#    2078 cube = self._ensure_save_result(format=format, options=options)
# -> 2079 return self._connection.download(cube.flat_graph(), outputfile, validate=validate)
#
# File ~/anaconda3/envs/gee/lib/python3.11/site-packages/openeo/rest/connection.py:1547, in Connection.download(self, graph, outputfile, timeout, validate)
#    1545 pg_with_metadata = self._build_request_with_process_graph(process_graph=graph)
#    1546 self._preflight_validation(pg_with_metadata=pg_with_metadata, validate=validate)
# -> 1547 response = self.post(
#    1548     path="/result",
#    1549     json=pg_with_metadata,
#    1550     expected_status=200,
#    1551     stream=True,
#    1552     timeout=timeout or DEFAULT_TIMEOUT_SYNCHRONOUS_EXECUTE,
#    1553 )
#    1555 if outputfile is not None:
#    1556     with Path(outputfile).open(mode="wb") as f:
#
# File ~/anaconda3/envs/gee/lib/python3.11/site-packages/openeo/rest/connection.py:218, in RestApiConnection.post(self, path, json, **kwargs)
#     210 def post(self, path: str, json: Optional[dict] = None, **kwargs) -> Response:
#     211     """
#     212     Do POST request to REST API.
#     213
#    (...)
#     216     :return: response: Response
#     217     """
# --> 218     return self.request("post", path=path, json=json, allow_redirects=False, **kwargs)
#
# File ~/anaconda3/envs/gee/lib/python3.11/site-packages/openeo/rest/connection.py:757, in Connection.request(self, method, path, headers, auth, check_error, expected_status, **kwargs)
#     750     return super(Connection, self).request(
#     751         method=method, path=path, headers=headers, auth=auth,
#     752         check_error=check_error, expected_status=expected_status, **kwargs,
#     753     )
#     755 try:
#     756     # Initial request attempt
# --> 757     return _request()
#     758 except OpenEoApiError as api_exc:
#     759     if api_exc.http_status_code in {401, 403} and api_exc.code == "TokenInvalid":
#     760         # Auth token expired: can we refresh?
#
# File ~/anaconda3/envs/gee/lib/python3.11/site-packages/openeo/rest/connection.py:750, in Connection.request.<locals>._request()
#     749 def _request():
# --> 750     return super(Connection, self).request(
#     751         method=method, path=path, headers=headers, auth=auth,
#     752         check_error=check_error, expected_status=expected_status, **kwargs,
#     753     )
#
# File ~/anaconda3/envs/gee/lib/python3.11/site-packages/openeo/rest/connection.py:165, in RestApiConnection.request(self, method, path, headers, auth, check_error, expected_status, **kwargs)
#     163 expected_status = ensure_list(expected_status) if expected_status else []
#     164 if check_error and status >= 400 and status not in expected_status:
# --> 165     self._raise_api_error(resp)
#     166 if expected_status and status not in expected_status:
#     167     raise OpenEoRestError("Got status code {s!r} for `{m} {p}` (expected {e!r}) with body {body}".format(
#     168         m=method.upper(), p=path, s=status, e=expected_status, body=resp.text)
#     169     )
#
# File ~/anaconda3/envs/gee/lib/python3.11/site-packages/openeo/rest/connection.py:197, in RestApiConnection._raise_api_error(self, response)
#     191         error_message = (
#     192             "Received 502 Proxy Error."
#     193             " This typically happens when a synchronous openEO processing request takes too long and is aborted."
#     194             " Consider using a batch job instead."
#     195         )
#     196     exception = OpenEoApiPlainError(message=text, http_status_code=status_code, error_message=error_message)
# --> 197 raise exception
#
# OpenEoApiError: [403] PermissionsInsufficient: Proper enrollment in openEO Platform virtual organization is required. (ref: r-23122076871543b2b55d633b8207b1dd)

# %%
import asf_search as asf
import geopandas as gpd
from shapely.geometry import Polygon, box
from datetime import date
import pandas as pd
import numpy as np
import requests
import os

# %%
def divide_bounds(min_y, max_y, n):
    
    north_lats = []
    south_lats = []
    step = (max_y - min_y) / n
    
    for i in range(n):
        north = max_y - i * step
        south = north - step
        north_lats.append(round(north, 1))
        south_lats.append(round(south, 1))
        
    return north_lats, south_lats

# %%
# overriding requests.Session.rebuild_auth to mantain headers when redirected
class SessionWithHeaderRedirection(requests.Session):

    AUTH_HOST = 'urs.earthdata.nasa.gov'
    def __init__(self, username, password):
        super().__init__()
        self.auth = (username, password)

   # Overrides from the library to keep headers when redirected to or from
   # the NASA auth host.
    def rebuild_auth(self, prepared_request, response):
        
        headers = prepared_request.headers
        url = prepared_request.url

        if 'Authorization' in headers:

            original_parsed = requests.utils.urlparse(response.request.url)
            redirect_parsed = requests.utils.urlparse(url)

            if ((original_parsed.hostname != redirect_parsed.hostname) and
                redirect_parsed.hostname != self.AUTH_HOST and 
                original_parsed.hostname != self.AUTH_HOST):
                del headers['Authorization']

        return

# %%
# set min and max lat and number of steps
min_y = 52
max_y = 72
min_x = -169.1
max_x = -139.8

# do it
norths, souths = divide_bounds(min_y, max_y, 8)
easts, wests = divide_bounds(min_x, max_x, 8)

# %%
nw = pd.DataFrame({'w':wests, 'n':norths})
ne = pd.DataFrame({'e':easts, 'n':norths})
sw = pd.DataFrame({'w':wests, 's':souths})
se = pd.DataFrame({'e':easts, 's':souths})

# %%
nw['nw'] = nw.values.tolist()
ne['ne'] = ne.values.tolist()
sw['sw'] = sw.values.tolist()
se['se'] = se.values.tolist()

# %%
all_urls = []
for i in range(1,len(nw)):
    
    # get bounds
    poly = Polygon([nw['nw'][i], ne['ne'][i], se['se'][i], sw['sw'][i]])
    bounds = poly.bounds
    gdf_bounds = gpd.GeoSeries([box(*bounds)], crs='EPSG:4326')
    wkt_aoi = gdf_bounds.to_wkt().values.tolist()[0]
    
    # initial query through asf
    asf.CMR_TIMEOUT = 60
    results = asf.search(platform=asf.PLATFORM.SENTINEL1,
                         processingLevel=[asf.PRODUCT_TYPE.GRD_HD, 
                                          asf.PRODUCT_TYPE.GRD_FD,
                                          asf.PRODUCT_TYPE.GRD_HS,
                                          asf.PRODUCT_TYPE.GRD_MD,
                                          asf.PRODUCT_TYPE.GRD_MS],
                         start=date(2019, 6, 1),
                         end=date(2019, 8, 31),
                         intersectsWith=wkt_aoi)

    # metadata to dictionary
    metadata = results.geojson()
    
    # get flight direction metadata
    direction = []
    for f in range(len(metadata['features'])):
        flightDirection = metadata['features'][f]['properties']['flightDirection']
        if flightDirection:
            direction.append(flightDirection)

    # determine flight path filter
    direction_counts = np.unique(direction, return_counts=True)
    if direction_counts[1][0] > direction_counts[1][1]:
        flight_path = direction_counts[0][0]
    else:
        flight_path = direction_counts[0][1]

    # filter by metadata properties
    asf.CMR_TIMEOUT = 60
    results = asf.search(platform=asf.PLATFORM.SENTINEL1,
                         processingLevel=[asf.PRODUCT_TYPE.GRD_HD, 
                                          asf.PRODUCT_TYPE.GRD_FD,
                                          asf.PRODUCT_TYPE.GRD_HS,
                                          asf.PRODUCT_TYPE.GRD_MD,
                                          asf.PRODUCT_TYPE.GRD_MS],
                         start=date(2019, 6, 1),
                         end=date(2019, 8, 31),
                         intersectsWith=wkt_aoi,
                         beamMode='IW',
                         flightDirection=flight_path)
    metadata = results.geojson()
    
    # get urls
    for f in range(len(metadata['features'])):    
        url = metadata['features'][f]['properties']['url']
        #if os.path.isfile(outpath) == False:
        all_urls.append(url)

# %%
EARTHDATA_USER='msteckler98'
EARTHDATA_PASS='E@rthd@t@1998!'
session = SessionWithHeaderRedirection(EARTHDATA_USER, EARTHDATA_PASS)

# %%
for url in all_urls:
    print(url)
# Out:
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190829T155510_20190829T155535_028786_0342B3_16CC.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190829T155441_20190829T155510_028786_0342B3_C79F.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190827T161126_20190827T161151_028757_0341B4_91B5.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190827T161101_20190827T161126_028757_0341B4_9913.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190827T161032_20190827T161101_028757_0341B4_0A1F.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190825T162747_20190825T162812_028728_0340B3_C627.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190825T162722_20190825T162747_028728_0340B3_630D.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190825T162653_20190825T162722_028728_0340B3_271F.zip
# https://datapool.asf.alaska.edu/GRD_HD/SB/S1B_IW_GRDH_1SDV_20190821T161013_20190821T161036_017686_021463_8E49.zip
# https://datapool.asf.alaska.edu/GRD_HD/SB/S1B_IW_GRDH_1SDV_20190821T160944_20190821T161013_017686_021463_CAF1.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190817T155510_20190817T155535_028611_033C8E_C0F9.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190817T155441_20190817T155510_028611_033C8E_61BD.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190815T161125_20190815T161150_028582_033B9B_7F88.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190815T161100_20190815T161125_028582_033B9B_75A0.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190815T161031_20190815T161100_028582_033B9B_F807.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190813T162747_20190813T162812_028553_033AA8_3AEB.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190813T162722_20190813T162747_028553_033AA8_6AA7.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190813T162653_20190813T162722_028553_033AA8_9035.zip
# https://datapool.asf.alaska.edu/GRD_HD/SB/S1B_IW_GRDH_1SDV_20190809T161013_20190809T161035_017511_020EEB_2481.zip
# https://datapool.asf.alaska.edu/GRD_HD/SB/S1B_IW_GRDH_1SDV_20190809T160943_20190809T161013_017511_020EEB_21D2.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190805T155509_20190805T155534_028436_0336A4_FFEB.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190805T155440_20190805T155509_028436_0336A4_9D1B.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190801T162746_20190801T162811_028378_0334F1_D87E.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20190801T162721_20190801T162746_028378_0334F1_E80F.zip
# https://datapool.asf.alaska.edu/GRD_HD/SA/S1A_IW_GRDH_1SDV_20
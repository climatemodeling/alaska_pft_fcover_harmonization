# %%
import phenolopy
import pandas as pd
import xarray as xr

# %%
# Parameters
BASE = '/mnt/poseidon/remotesensing/arctic/data/training/Test_05/features'
PC = 'parent'
INFO  = 'ndvi_2019_med'
BUFF = '30'
timeseries = f'{BASE}/{PC}/{PC}_{INFO}_{BUFF}m.csv'

# %%
pd.read_csv(timeseries)
# Out:
#       Site Code  2019-01-01  2019-02-01  2019-03-01  2019-04-01  2019-05-01  \
# 0       FMTT-5B         NaN    0.016180   -0.021552    0.006316   -0.045562
# 1       FWMM-5B         NaN    0.016788   -0.019643   -0.016807   -0.059410
# 2         AB-1B         NaN    0.125160    0.015723    0.090721    0.205713
# 3        FMTT-1         NaN    0.022501   -0.005457    0.009119   -0.059892
# 4        AFMM-5         NaN    0.015719   -0.009471    0.007514    0.095958
# ..          ...         ...         ...         ...         ...         ...
# 510  84_2017_SP         NaN   -0.118193   -0.048913   -0.044583   -0.079523
# 511  85_2017_SP         NaN         NaN   -0.051497   -0.049636   -0.075248
# 512   8_2018_SP         NaN   -0.023108   -0.000786   -0.052677    0.428372
# 513   9_2018_SP         NaN   -0.020542    0.000997   -0.052124    0.245234
# 514     TMCW-64         NaN         NaN         NaN         NaN         NaN
#
# ...
